# %% [markdown]
# $$
# F
# =
# \frac{SS_{\text{trt}}/(a-1)}
# {SS_E/\big(a(n-1)\big)}
# =
# \frac{\chi^2_{a-1}/(a-1)}
# {\chi^2_{a(n-1)}/\big(a(n-1)\big)}
# $$
# **make sure the numderator and denominator are independent for the ratio to be F distribution**

# %% [markdown]
# $$
# t
# =
# \frac{
# \displaystyle
# \frac{\bar{Y}_{i\cdot} - \mu_i}{\sqrt{\sigma^2/n}}
# }{
# \displaystyle
# \sqrt{\frac{SSE/\sigma^2}{a(n-1)}}
# }
# =
# \frac{\bar{Y}_{i\cdot} - \mu_i}{\sqrt{MSE/n}}
# \sim t_{a(n-1)}.
# $$
