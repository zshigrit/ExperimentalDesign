# %% [markdown]
# # example for a fun test of t test for unpaired, paired and paired with additional design
# - one point i am trying to prove is that for the paired t test, the manual calculation $(\sum \delta_i / N)/sd(\delta)$ is for the paired t without the additional desgin.
